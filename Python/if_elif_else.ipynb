# %% [markdown]
# ![image.png](attachment:image.png)

# %%
if 25 > 10:
    print('Deu boa!')
# Out:
# Deu boa!

# %%
if 25 < 10:
    print('Deu boa!')
else:
    print('Não deu boa...')
# Out:
# Não deu boa...

# %%
if (25 < 10) or (1 < 3):
    print('Deu boa!')
elif 25 < 20:
    print('elif funcionou')
elif 25 < 21:
    print('elif 2 funcionou')
elif 25 < 40:
    print('elif 3 funcionou')
else:
    print('Não deu boa...')
# Out:
# Deu boa!

# %%
print('Funcionou') if 10 > 30 else print('Não funcionou...')
# Out:
# Não funcionou...

# %%
if (25 < 10) or (1 < 3):
    print('Deu boa!')
    if 10 > 5:
        print('If aninhado funcionou!')
elif 25 < 20:
    print('elif funcionou')
elif 25 < 21:
    print('elif 2 funcionou')
elif 25 < 40:
    print('elif 3 funcionou')
else:
    print('Não deu boa...')
# Out:
# Deu boa!
# If aninhado funcionou!
